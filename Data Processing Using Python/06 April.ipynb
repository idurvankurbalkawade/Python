# %% [markdown]
# ## ChartStyles

# %%
import matplotlib.pyplot as plt

from matplotlib import style

import numpy as np

y=np.array([35,25,25,15])

subjectlabel=["English","Maths","Science","Geography"]

plt.pie(y,labels=subjectlabel)

style.use('seaborn-bright')

plt.show()

# %%
import matplotlib.pyplot as plt

from matplotlib import style

import numpy as np

y=np.array([35,25,25,15])

subjectlabel=["English","Maths","Science","Geography"]

plt.pie(y,labels=subjectlabel)

style.use('grayscale')

plt.show()

# %%
print(plt.style.available)
# Out:
# ['Solarize_Light2', '_classic_test_patch', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn', 'seaborn-bright', 'seaborn-colorblind', 'seaborn-dark', 'seaborn-dark-palette', 'seaborn-darkgrid', 'seaborn-deep', 'seaborn-muted', 'seaborn-notebook', 'seaborn-paper', 'seaborn-pastel', 'seaborn-poster', 'seaborn-talk', 'seaborn-ticks', 'seaborn-white', 'seaborn-whitegrid', 'tableau-colorblind10']

# %%
import matplotlib.pyplot as plt

from matplotlib import style

import numpy as np

y=np.array([35,25,25,15])

subjectlabel=["English","Maths","Science","Geography"]

plt.pie(y,labels=subjectlabel)

style.use('dark_background')

plt.show()

# %% [markdown]
# ## Assignment Questions

# %%
import matplotlib.pyplot as plt
from matplotlib import style
import numpy as np
arr1=np.array([5,10,15,25,10,15,20])
labels=["Transport","House Rent","Education for Children","Food","Clothes","Savings","Others"]
plt.pie(arr1,labels=labels)
style.use('grayscale')
plt.show()

# %%
import matplotlib.pyplot as plt
from matplotlib import style
import numpy as np
arr2=np.array([20,40,30,10])
dancetype=["Semi Classical","Light","Folk","Classical"]
plt.pie(arr2,labels=dancetype)
style.use('grayscale')
plt.show()

# %%
import matplotlib.pyplot as plt
from matplotlib import style
import numpy as np
arr2=np.array([20,40,30,10])
dancetype=["Semi Classical","Light","Folk","Classical"]
plt.pie(arr2,labels=dancetype)
style.use('seaborn-bright')
plt.show()

# %% [markdown]
# ## Time Series

# %%
from datetime import datetime

import pandas as pd

import matplotlib.pyplot as plt



data = pd.read_csv('goldsilver.csv')

df = pd.DataFrame(data, columns = ['Date', 'Gold22k'])



# Set the Date as Index

df['Date'] = pd.to_datetime(df['Date'])

df.index = df['Date']

del df['Date']




df.plot(figsize=(8, 6))

plt.show()
